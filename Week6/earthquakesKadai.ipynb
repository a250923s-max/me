# %%
number  = input('あなたの知りたい情報を教えてください！')
number  = int (number)

import pandas as pd
import requests

# USGSから過去1か月の地震データを取得
url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv"
response = requests.get(url)

# データをファイルに保存
with open('earthquakes.csv', 'wb') as file:
    file.write(response.content)

# データをDataFrameに読み込む
data = pd.read_csv('earthquakes.csv')

# データの最初の5行を表示
data.head(number)
# Out:
#                        time   latitude   longitude     depth   mag magType  \
# 0  2025-11-11T17:10:08.350Z  32.063000 -101.676000    1.8428  1.30      ml
# 1  2025-11-11T17:08:54.850Z  36.470665 -121.088837    6.0300  1.33      md
# 2  2025-11-11T16:35:50.930Z  38.832001 -122.817337    1.7100  0.75      md
# 3  2025-11-11T16:10:27.350Z  61.549100 -148.342200    9.3000  1.50      ml
# 4  2025-11-11T15:54:30.340Z  34.195000 -117.481333    3.3900  2.36      ml
# 5  2025-11-11T15:50:43.840Z  38.790833 -122.760498    1.3500  1.12      md
# 6  2025-11-11T15:50:19.791Z  60.688500 -150.564400   35.5000  2.30      ml
# 7  2025-11-11T15:42:48.304Z  64.973800 -147.366200    7.3000  1.40      ml
# 8  2025-11-11T15:27:54.600Z  19.358166 -155.073334    4.2400  2.61      md
# 9  2025-11-11T15:12:52.980Z -25.083200  179.832300  503.7660  4.60      mb
#
#      nst    gap      dmin   rms  ...                   updated  \
# 0   14.0   86.0  0.100000  0.70  ...  2025-11-11T17:13:14.998Z
# 1   17.0   58.0  0.029240  0.26  ...  2025-11-11T17:10:31.953Z
# 2    7.0   71.0  0.015630  0.00  ...  2025-11-11T16:52:17.416Z
# 3    NaN    NaN       NaN  0.78  ...  2025-11-11T16:12:25.472Z
# 4  133.0   26.0  0.019800  0.23  ...  2025-11-11T16:43:28.205Z
# 5   11.0   74.0  0.009797  0.02  ...  2025-11-11T17:17:20.516Z
# 6    NaN    NaN       NaN  0.74  ...  2025-11-11T15:57:33.048Z
# 7    NaN    NaN       NaN  0.32  ...  2025-11-11T15:45:12.793Z
# 8   55.0  143.0  0.044070  0.26  ...  2025-11-11T15:31:56.400Z
# 9   27.0  135.0  7.488000  0.86  ...  2025-11-11T15:29:11.040Z
#
#                               place        type horizontalError depthError  \
# 0        12 km SE of Stanton, Texas  earthquake            0.00   1.841656
# 1          8 km SE of Pinnacles, CA  earthquake            0.56   1.700000
# 2        8 km NW of The Geysers, CA  earthquake            0.35   1.140000
# 3   28 km SSE of Chickaloon, Alaska  earthquake             NaN   0.300000
# 4       7 km SSE of Lytle Creek, CA  earthquake            0.12   0.300000
# 5       2 km NNW of The Geysers, CA  earthquake            0.28   0.550000
# 6     20 km NNE of Sterling, Alaska  earthquake             NaN   1.300000
# 7            12 km E of Fox, Alaska  earthquake             NaN   0.800000
# 8  13 km SSE of Fern Forest, Hawaii  earthquake            0.48   0.740000
# 9         south of the Fiji Islands  earthquake           15.87  11.322000
#
#    magError  magNst     status  locationSource magSource
# 0  0.200000     9.0  automatic              tx        tx
# 1  0.190000    12.0  automatic              nc        nc
# 2  0.170000     8.0  automatic              nc        nc
# 3       NaN     NaN  automatic              ak        ak
# 4  0.181000    25.0  automatic              ci        ci
# 5  0.160000    10.0  automatic              nc        nc
# 6       NaN     NaN  automatic              ak        ak
# 7       NaN     NaN  automatic              ak        ak
# 8  0.081823    13.0  automatic              hv        hv
# 9  0.085000    42.0   reviewed              us        us
#
# [10 rows x 22 columns]

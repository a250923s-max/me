# %%
import pandas as pd

df = pd.read_csv("BikeDorobou.csv")
df.head()

df.groupby('手口').size().sort_values(ascending=False)
# Out:
# 手口
# 自転車盗    9943
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("BikeDorobou.csv")
df.head()
